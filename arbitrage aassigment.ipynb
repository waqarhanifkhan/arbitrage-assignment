# %%
import requests as r
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
def crypto_defrence(fiat = 'btc', crypto = 'usd'):
    url = 'https://api.cryptonator.com/api/full/{}-{}'.format(fiat, crypto)
    df = pd.DataFrame(r.get(url).json()['ticker']['markets'])
    df['price']  = df['price'].astype('float')
    y, x , n=list(df['volume']),list(df['price']),list(df['market'])  
    plt.figure(figsize=(30,20)), plt.scatter(x, y, s=150)
    for i, txt in enumerate(n): plt.annotate(txt, (x[i],y[i])) 
    plt.rc('xtick', labelsize=30) 
    plt.rc('ytick', labelsize=30) 
    plt.rcParams.update({'font.size': 30})
    print('minimum price at:\n',end='');print((df[df['price'] == np.min(df['price'])]))
    print('\nmaximum price at:\n');print((df[df['price'] == np.max(df['price'])]))
    print('\ndefrence between minimum and meximum:\n',end=''); print(np.max(df['price']) - np.min(df['price']))
    plt.show(); return ' '
print(crypto_defrence('btc', 'usd'))
# Out:
# minimum price at:
#    market   price       volume
# 7  Kraken  6687.4  7265.210484
#
# maximum price at:
#
#      market       price       volume
# 8  Livecoin  7125.49985  1553.914438
#
# defrence between minimum and meximum:
# 438.0998500000005

# %%
print(crypto_defrence())
# Out:
# minimum price at:
#    market   price       volume
# 7  Kraken  6680.2  7264.339375
#
# maximum price at:
#
#      market   price       volume
# 8  Livecoin  7127.1  1548.532618
#
# defrence between minimum and meximum:
# 446.90000000000055

# %%
print(crypto_defrence('eth', 'usd'))
# Out:
# minimum price at:
#      market       price        volume
# 8  Poloniex  375.461211  13529.867745
#
# maximum price at:
#
#   market      price    volume
# 2  C-Cex  410.63895  0.177747
#
# defrence between minimum and meximum:
# 35.17773899000002

# %%
print(crypto_defrence('eth', 'eur'))
# Out:
# minimum price at:
#    market  price        volume
# 3  Kraken  304.3  38789.839557
#
# maximum price at:
#
#   market       price      volume
# 2   Exmo  315.553139  1001.77212
#
# defrence between minimum and meximum:
# 11.253138680000006
